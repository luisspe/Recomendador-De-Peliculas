# %% [markdown]
# # **Este es un software de recomendación de peliculas**

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# **Importamos los datos**

# %%
#importamos los datos
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd4e7a55-a892-44e2-a909-a6dd139e8230" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd4e7a55-a892-44e2-a909-a6dd139e8230">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movie-data.csv to movie-data.csv

# %% [markdown]
# **Analizamos la tabla y agregamos la columna de id (0,1,2...)**

# %%
df = pd.read_csv('movie-data.csv')
df['Movie_id'] = range(0,1000)
df.head(3)
# Out:
#    Rank                    Title  ... Metascore Movie_id
# 0     1  Guardians of the Galaxy  ...      76.0        0
# 1     2               Prometheus  ...      65.0        1
# 2     3                    Split  ...      62.0        2
#
# [3 rows x 13 columns]

# %%
#llevar una cuneta de el numero de peliculas en el data set y el numero de columnas
df.shape
# Out:
# (1000, 13)

# %%
#crear una lista para las columnas importantes que seran usadas
columns = ['Actors', 'Director', 'Genre', 'Title']

# %%
#mostramos los datos
df[columns].head(3)
# Out:
#                                               Actors  ...                    Title
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  ...  Guardians of the Galaxy
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  ...               Prometheus
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  ...                    Split
#
# [3 rows x 4 columns]

# %%
#revisar si hay algun valor faltante en las columnas importantes
df[columns].isnull().values.any()
# Out:
# False

# %%
#crear una funcion para combinar los valores de las columnas importantes en una solo string
def get_imortant_features(data):
  important_features = []
  for i in range(0,data.shape[0]):
    important_features.append(data['Actors'][i]+' '+data['Director'][i]+' '+data['Genre'][i]+' '+data['Title'][i])
  return important_features

# %%
#crear una columna para sotener los string combinados
df['important_features'] = get_imortant_features(df)
#mostrar los datos
df.head(3)
# Out:
#    Rank  ...                                 important_features
# 0     1  ...  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1     2  ...  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2     3  ...  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
#
# [3 rows x 14 columns]

# %%
#convertir el texto a una matrix de token counts
cm = CountVectorizer().fit_transform(df['important_features'])

# %%
#conseguir el coseno de similaridad matrix de count matrix
cs = cosine_similarity(cm)
#imprimir el coseno de similaridad
print(cs)
# Out:
# [[1.         0.1767767  0.06085806 ... 0.0571662  0.06537205 0.        ]
#  [0.1767767  1.         0.         ... 0.         0.06933752 0.        ]
#  [0.06085806 0.         1.         ... 0.         0.         0.        ]
#  ...
#  [0.0571662  0.         0.         ... 1.         0.06726728 0.        ]
#  [0.06537205 0.06933752 0.         ... 0.06726728 1.         0.07161149]
#  [0.         0.         0.         ... 0.         0.07161149 1.        ]]

# %%
#conseguir la forma de la cosine similarity matrix
cs.shape
# Out:
# (1000, 1000)

# %%
#conseguir el titulo de la pelicula que el usuario quiere
title = 'Guardians of the Galaxy'
#encontrar el id de la pelicula
movie_id = df[df.Title == title]['Movie_id'].values[0] # el valor es 0 porque asi conseguimos su numero no el nombre
print(movie_id)
# Out:
# 0

# %%
#crear una lista de numeraciones para el puntaje de similaridad[(move_id, similarity_score), (...)]
scores = list(enumerate(cs[movie_id]))
 0.23570226039551587), (287, 0.23570226039551587), (315, 0.23570226039551587), (389, 0.23570226039551587), (454, 0.23570226039551587), (528, 0.23570226039551587), (541, 0.23570226039551587), (542, 0.23570226039551587), (552, 0.23570226039551587), (673, 0.23570226039551587), (764, 0.23570226039551587), (313, 0.2311250817605122), (15, 0.2286647801900118), (24, 0.2286647801900118), (107, 0.2286647801900118), (151, 0.2286647801900118), (203, 0.2286647801900118), (214, 0.2286647801900118), (268, 0.2286647801900118), (450, 0.2286647801900118), (491, 0.2286647801900118), (575, 0.2286647801900118), (799, 0.2286647801900118), (878, 0.2286647801900118), (879, 0.2286647801900118), (67, 0.22222222222222227), (234, 0.22222222222222227), (243, 0.22222222222222227), (279, 0.22222222222222227), (371, 0.22222222222222227), (564, 0.22222222222222227), (871, 0.22222222222222227), (948, 0.22222222222222227), (990, 0.22222222222222227), (34, 0.21629522817435004), (156, 0.21629522817435004), (45, 0.21081851067789198), (75, 0.21081851067789198), (78, 0.21081851067789198), (500, 0.21081851067789198), (518, 0.21081851067789198), (135, 0.2057377999494559), (264, 0.2057377999494559), (314, 0.19658927487319622), (255, 0.19611613513818404), (244, 0.1924500897298753), (629, 0.1924500897298753), (9, 0.18898223650461363), (26, 0.18898223650461363), (91, 0.18898223650461363), (101, 0.18898223650461363), (134, 0.18898223650461363), (204, 0.18898223650461363), (370, 0.18898223650461363), (386, 0.18898223650461363), (446, 0.18898223650461363), (492, 0.18898223650461363), (613, 0.18490006540840975), (36, 0.18257418583505536), (217, 0.18257418583505536), (239, 0.18257418583505536), (319, 0.18257418583505536), (331, 0.18257418583505536), (340, 0.18257418583505536), (379, 0.18257418583505536), (512, 0.18257418583505536), (526, 0.18257418583505536), (559, 0.18257418583505536), (731, 0.18257418583505536), (766, 0.18257418583505536), (904, 0.18257418583505536), (1, 0.1767766952966369), (5, 0.1767766952966369), (51, 0.1767766952966369), (64, 0.1767766952966369), (97, 0.1767766952966369), (104, 0.1767766952966369), (131, 0.1767766952966369), (294, 0.1767766952966369), (323, 0.1767766952966369), (345, 0.1767766952966369), (368, 0.1767766952966369), (404, 0.1767766952966369), (432, 0.1767766952966369), (481, 0.1767766952966369), (529, 0.1767766952966369), (532, 0.1767766952966369), (533, 0.1767766952966369), (537, 0.1767766952966369), (553, 0.1767766952966369), (576,  ...

# %%
#crear un loop para imprimir las primeras 7 peliculas similares
j = 0
print(" the 7 most recomoended movies to ",title, 'are:')
for item in sorted_scores:
  movie_title = df[df.Movie_id == item[0]]['Title'].values[0]
  print(j+1, movie_title)
  j = j +1
  if j > 6:
    break
# Out:
#  the 7 most recomoended movies to  Split are:
# 1 Morgan
# 2 The Conjuring
# 3 The Visit
# 4 Victor Frankenstein
# 5 The VVitch: A New-England Folktale
# 6 Insidious
# 7 Mama
